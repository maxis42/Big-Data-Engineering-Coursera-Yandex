# %% [markdown]
# ## Assignment 2: TF-IDF
# In this task Hadoop Streaming is used to process Wikipedia articles dump.
#
# Dataset location: /data/wiki/en_articles_part
#
# Stop words list is in ‘/datasets/stop_words_en.txt’ file.
#
# Format: article_id <tab> article_text
#
# To parse the articles don’t forget about Unicode (even though this is an English Wikipedia dump, there are many characters from other languages), remove punctuation marks and transform words to lowercase to get the correct quantities. To cope with Unicode we recommend to use the following tokenizer:
#
# ```python
# #!/usr/bin/env python
#
# import sys
# import re
#
# reload(sys)
# sys.setdefaultencoding('utf-8')
#
# for line in sys.stdin:
#     try:
#         article_id, text = unicode(line.strip()).split('\t', 1)
#     except ValueError as e:
#         continue
#     text = re.sub("^\W+|\W+$", "", text, flags=re.UNICODE)
#     words = re.split("\W*\s+\W*", text, flags=re.UNICODE)
#     ...
# ```
# Calculate tf*idf for each pair (word, article) from the Wikipedia dump. Apply the stop words filter to speed up calculations. Term frequency (tf) is a function depending on a term (word) and a document (article):
#
# tf(term, doc_id) = Nt/N,
#
# where Nt - quantity of particular term in the document, N - the total number of terms in the document (without stop words)
#
# Inverse document frequency (idf) is a function depends on a term:
#
# idf(term) = 1/log(1 + Dt),
#
# where Dt - number of documents in the dataset with the particular term.
#
# You can find more information here: https://en.wikipedia.xn--org/wiki/Tfidf-q82h but use just the formulas mentioned above.
#
# Output: tf*idf for term=’labor’ and article_id=12
#
# *Hint: all Wikipedia article_ids are greater than 0. So you can use a dummy article_id=0 to calculate the number of documents with each term.*

# %%
# %%writefile mapper.py
from __future__ import division
import sys
import re
from collections import Counter

reload(sys)
sys.setdefaultencoding('utf-8') # required to convert to unicode

with open('stop_words_en.txt') as f:
    stop_words = set(f.read().split())

for line in sys.stdin:
    try:
        article_id, text = unicode(line.strip()).split('\t', 1)
        article_id = int(article_id)
    except ValueError as e:
        continue
    words = re.split("\W*\s+\W*", text, flags=re.UNICODE)
    words = [x.lower() for x in words if x.lower() not in stop_words]
    words_set = set(words)
    
    num_of_words_in_doc = len(words)
    counts = Counter(words)
    
    for word in words_set:
        num_of_word_in_doc = counts[word]
        tf = num_of_word_in_doc / num_of_words_in_doc
        print "%s\t%d\t%f" % (word, article_id, tf)
# Out:
# Overwriting mapper.py

# %%
# %%writefile reducer.py
from __future__ import division
import sys
from math import log

current_word = None
articles_dict = dict()

for line in sys.stdin:
    try:
        word, article_id, tf = line.strip().split('\t')
        article_id = int(article_id)
        tf = float(tf)
    except ValueError as e:
        continue
    
    if current_word != word:
        if current_word:
            idf = 1 / log(1 + len(articles_dict))
            for key_article_id, tf in articles_dict.iteritems():
                tfidf = tf * idf
                print "%s\t%d\t%f" % (current_word, key_article_id, tfidf)
        articles_dict = dict()
        current_word = word
    articles_dict[article_id] = tf

if current_word:
    print "%s\t%d\t%f" % (current_word, article_id, tfidf)
# Out:
# Writing reducer.py

# %%
# !hdfs dfs -cat /data/wiki/en_articles_part/articles-part | head -2 > test_file.txt
# !cp /datasets/stop_words_en.txt stop_words_en.txt
# !cat test_file.txt | python2 mapper.py | sort -k1,1 | python2 reducer.py
# Out:
# cat: Unable to write to output stream.
# 0-00-634011-3	12	0.000237
# 0.02	25	0.000237
# 0.5	25	0.000237
# 0.6	25	0.000237
# 0.7	25	0.000237
# 0-7546-6196-2	12	0.000237
# 0-8490-1397-6	12	0.000237
# 0-85345-175-3	12	0.000237
# 0.9	25	0.000237
# 1	12	0.000237
# 10	25	0.000661
# 10	12	0.000149
# 1000	25	0.000237
# 1,000	25	0.000237
# 100,000	12	0.000237
# 10–15	25	0.000237
# 11	25	0.000237
# 111-113	12	0.000237
# 119	12	0.000237
# 12	25	0.000237
# 1–2	25	0.000237
# 126	12	0.000237
# 12-year-old	25	0.000237
# 14	25	0.000441
# 14	12	0.000149
# 15	25	0.000661
# 15	12	0.000149
# 1-55164-250-6	12	0.000237
# 1-55164-251-4	12	0.000237
# 1.58	12	0.000237
# 15q13.3	25	0.000237
# 16	25	0.000237
# 1-60486-064-2	12	0.000237
# 1642	12	0.000237
# 16p13.1	25	0.000237
# 17	25	0.000237
# 1747	25	0.000237
# 179	12	0.000237
# 1793	12	0.000237
# 1794	12	0.000237
# 1796	12	0.000237
# 1798	25	0.000237
# 17p12	25	0.000237
# 17th	12	0.000237
# 18	25	0.000441
# 18	12	0.000149
# 1817–1862	12	0.000237
# 183	12	0.000237
# 18–30	25	0.000237
# 1833	12	0.000237
# 1842	12	0.000237
# 1844	12	0.000237
# 1848	12	0.000237
# 1849–1898	12	0.000237
# 1864	12	0.000237
# 1864–1892	12	0.000237
# 1868	12	0.000237
# 1870	12	0.000237
# 1871	12	0.000237
# 1-871082-16-1	12	0.000237
# 1872	12	0.000237
# 1872–1890	12	0.000237
# 1880s	12	0.000237
# 1881	12	0.000237
# 1883–1907	12	0.000237
# 1886	12	0.000237
# 1887	12	0.000237
# 1889	12	0.000237
# 1890	12	0.000237
# 1890–1939	12	0.000237
# 1890s	12	0.000237
# 1892–1893	12	0.000237
# 1894	12	0.000237
# 1895	12	0.000237
# 1895–1897	12	0.000237
# 1896	12	0.000237
# 1897	12	0.000237
# 1897–1904	12	0.000237
# 18th	12	0.000237
# 19	25	0.000237
# 1901	12	0.000237
# 1902–1909	12	0.000237
# 1905	12	0.000237
# 1906	12	0.000237
# 1907	12	0.000237
# 1910	25	0.000220
# 1910	12	0.000149
# 1910s	12	0.000237
# 1911	12	0.000237
# 1914	12	0.000237
# 1914–1918	12	0.000237
# 1917	12	0.000237
# 1917–23	12	0.000237
# 1918–1919	12	0.000237
# 1919	12	0.000237
# 1920	12	0.000237
# 1920s	12	0.000237
# 1921	12	0.000237
# 1922	12	0.000237
# 1923	12	0.000237
# 1923–1938	12	0.000237
# 1926	12	0.000237
# 1930s	12	0.000237
# 1933	12	0.000237
# 1934	12	0.000237
# 1936	12	0.000237
# 1936–1939	12	0.000237
# 1938	25	0.000220
# 1938	12	0.000149
# 1939	12	0.000237
# 1939–1977	12	0.000237
# 1939–2006	12	0.000237
# 1940s	12	0.000237
# 1943	25	0.000237
# 1944	12	0.000237
# 1945	12	0.000237
# 1946	12	0.000237
# 1947	12	0.000237
# 1948	12	0.000237
# 1950s	12	0.000237
# 1953	12	0.000237
# 1955	12	0.000237
# 1956	12	0.000237
# 1960s	25	0.000220
# 1960s	12	0.000149
# 1962	12	0.000237
# 1968	12	0.000237
# 1970	12	0.000237
# 1970s	12	0.000237
# 1971	12	0.000237
# 1977	12	0.000237
# 1979	12	0.000237
# 1980	25	0.000237
# 1980s	25	0.000237
# 1981	25	0.000237
# 1982	12	0.000237
# 1987	12	0.000237
# 1990	12	0.000237
# 1990s	25	0.000237
# 1991	12	0.000237
# 1992	12	0.000237
# 1994	12	0.000237
# 1994–95	12	0.000237
# 1999	12	0.000237
# 19th	12	0.000237
# 1q21.1	25	0.000237
# 2	12	0.000237
# 20	25	0.000220
# 20	12	0.000149
# 2000	25	0.000220
# 2000	12	0.000149
# 2,000	12	0.000237
# 20,000	12	0.000237
# 2000s	25	0.000237
# 2001	12	0.000237
# 2002	12	0.000237
# 2003	25	0.000220
# 2003	12	0.000149
# 2004	25	0.000220
# 2004	12	0.000149
# 2005	25	0.000441
# 2005	12	0.000149
# 2006	12	0.000237
# 2007	25	0.000441
# 2007	12	0.000149
# 2007-12-13	12	0.000237
# 2008	25	0.001541
# 2008	12	0.000149
# 2009	25	0.000220
# 2009	12	0.000149
# 2010	12	0.000237
# 2010-12-29	12	0.000237
# 2012	12	0.000237
# 2013	25	0.000237
# 20th	12	0.000237
# 21	12	0.000237
# 2:1	25	0.000237
# 21st	12	0.000237
# 24	25	0.000237
# 25	25	0.000237
# 26	12	0.000237
# 27	25	0.000237
# 28	12	0.000237
# 2nd	12	0.000237
# 3	25	0.000220
# 3	12	0.000149
# 30	25	0.000237
# 300ce	12	0.000237
# 300ce-1939	12	0.000237
# 31	12	0.000237
# 32	25	0.000237
# 3.7	25	0.000237
# 4	25	0.000441
# 4	12	0.000149
# 40	25	0.000237
# 4.3:1	25	0.000237
# 46	25	0.000237
# 48	25	0.000237
# 5	25	0.000237
# 50	25	0.000237
# 51	12	0.000237
# 54	12	0.000237
# 550	12	0.000237
# 5.5:1	25	0.000237
# 558	12	0.000237
# 56	25	0.000237
# 5.7	25	0.000237
# 6	25	0.000237
# 60	25	0.000237
# 60%–80	25	0.000237
# 62	12	0.000237
# 67	25	0.000237
# 68	25	0.000237
# 6th	12	0.000237
# 7	12	0.000237
# 70	25	0.000237
# 700	12	0.000237
# 75	12	0.000237
# 768	12	0.000237
# 78	25	0.000237
# 8	25	0.000220
# 8	12	0.000149
# 800,000	12	0.000237
# 8–15	25	0.000237
# 82	12	0.000237
# 84	25	0.000237
# 9	12	0.000237
# 90	25	0.000237
# 978-0-06-136050-3	12	0.000237
# 978-1-55164-311-3	12	0.000237
# 978-1-84935-122-5	12	0.000237
# 978-1-902593-90-6	12	0.000237
# 99	12	0.000237
# à	12	0.000237
# aa	12	0.000237
# aba	25	0.000237
# abandoned	12	0.000237
# abandoning	12	0.000237
# abandonment	12	0.000237
# abbreviated	25	0.000237
# abc-clio	12	0.000237
# aberrant	25	0.000237
# abilities	25	0.000237
# ability	25	0.000661
# ability	12	0.000149
# able	12	0.000237
# abnormal	25	0.000237
# abnormalities	25	0.000237
# abnormality	25	0.000237
# abolishes	12	0.000237
# abolition	12	0.000237
# absolute	25	0.000237
# abstention	12	0.000237
# abstentionism	12	0.000237
# abuse	12	0.000237
# accept	12	0.000237
# acceptance	12	0.000237
# accepted	25	0.000237
# accepting	12	0.000237
# according	25	0.000220
# according	12	0.000149
# accordingly	12	0.000237
# account	25	0.000441
# account	12	0.000149
# accounted	25	0.000237
# accounts	12	0.000237
# accurate	25	0.000237
# achieve	12	0.000237
# achieved	25	0.000441
# achieved	12	0.000149
# achieving	12	0.000237
# acquire	25	0.000237
# acquiring	25	0.000237
# act	25	0.000220
# act	12	0.000149
# action	25	0.000441
# action	12	0.000149
# actions	25	0.000220
# actions	12	0.000149
# action—that	12	0.000237
# activation	25	0.000237
# active	25	0.000441
# active	12	0.000149
# actively	12	0.000237
# activism	12	0.000237
# activist	12	0.000237
# activists	12	0.000237
# activities	25	0.000237
# activity	25	0.001321
# activity	12	0.000149
# activity-dependent	25	0.000237
# acts	12	0.000237
# actual	25	0.000237
# ad	12	0.000237
# addition	12	0.000237
# address	25	0.000441
# address	12	0.000149
# adequate	25	0.000237
# adhd	25	0.000237
# adhesion	25	0.000237
# adi-r	25	0.000237
# adjectives	12	0.000237
# adjustments	25	0.000237
# admiration	25	0.000237
# admit	12	0.000237
# adolescence	25	0.000237
# adolescents	25	0.000237
# adolf	12	0.000237
# adopted	25	0.000220
# adopted	12	0.000149
# adopting	12	0.000237
# ados	25	0.000237
# adult	25	0.000237
# adulthood	25	0.000237
# adults	25	0.002642
# adults	12	0.000149
# advanced	25	0.000220
# advanced	12	0.000149
# advantage	12	0.000237
# adverse	25	0.000237
# advocate	12	0.000237
# advocated	12	0.000237
# advocates	12	0.000237
# advocating	12	0.000237
# affair	12	0.000237
# affect	25	0.001541
# affect	12	0.000149
# affected	25	0.000237
# affects	25	0.000237
# affiliated	12	0.000237
# affinity	12	0.000237
# aforementioned	12	0.000237
# after.beyond	12	0.000237
# age	25	0.000237
# aged	25	0.000237
# agents	25	0.000661
# agents	12	0.000149
# aggression	25	0.000661
# aggression	12	0.000149
# agitating	12	0.000237
# agrarian	12	0.000237
# aid	25	0.000220
# aid	12	0.000149
# aims	12	0.000237
# ak	12	0.000237
# al	12	0.000237
# alain	12	0.000237
# albert	12	0.000237
# alcohol	25	0.000237
# alex	12	0.000237
# alexander	12	0.000237
# alexandre	12	0.000237
# alistair	12	0.000237
# alive	12	0.000237
# allen	12	0.000237
# alliance	12	0.000237
# allied	12	0.000237
# allow	12	0.000237
# allowances	25	0.000237
# allows	25	0.000237
# ally	12	0.000237
# aloneness	25	0.000237
# alongside	12	0.000237
# alrededor	12	0.000237
# alteration	25	0.000237
# altering	25	0.000237
# alternative	25	0.000441
# alternative	12	0.000149
# america	12	0.000237
# american	12	0.000237
# americans	12	0.000237
# ammon	12	0.000237
# amoureuse	12	0.000237
# amoureux	12	0.000237
# amsterdam	12	0.000237
# analysing	12	0.000237
# analysis	25	0.000237
# anarcha-feminism	12	0.000237
# anarcha-feminist	12	0.000237
# anarcha-feminists	12	0.000237
# anarchica	12	0.000237
# anarchism	12	0.000237
# anarchism:left	12	0.000237
# anarchisms	12	0.000237
# anarchism's	12	0.000237
# anarchist	12	0.000237
# anarchist-communism	12	0.000237
# anarchist-communists	12	0.000237
# anarchiste	12	0.000237
# anarchistes	12	0.000237
# anarchistic	12	0.000237
# anarchist-inspired	12	0.000237
# anarchists	12	0.000237
# anarcho-capitalism	12	0.000237
# anarcho-communism	12	0.000237
# anarcho-communist	12	0.000237
# anarcho-communists	12	0.000237
# anarcho-hedonist	12	0.000237
# anarcho-naturism	12	0.000237
# anarcho-pacifism	12	0.000237
# anarcho-pacifist	12	0.000237
# anarcho-pacifists	12	0.000237
# anarcho-primitivism	12	0.000237
# anarchos	12	0.000237
# anarcho-syndicalism	12	0.000237
# anarcho-syndicalism.the	12	0.000237
# anarcho-syndicalist	12	0.000237
# anarcho-syndicalists	12	0.000237
# anarchy	12	0.000237
# anarquismo	12	0.000237
# anarquista	12	0.000237
# ancient	12	0.000237
# andalusia	12	0.000237
# anderson	12	0.000237
# andré	12	0.000237
# andrej	12	0.000237
# andrej(2004)anarchism	12	0.000237
# andrews	12	0.000237
# anecdotal	25	0.000237
# angela	12	0.000237
# animal	25	0.000441
# animal	12	0.000149
# annual	25	0.000220
# annual	12	0.000149
# annul	25	0.000237
# anomalies	25	0.000237
# anomaly	25	0.000237
# anonymous	12	0.000237
# anselme	12	0.000237
# anthology	12	0.000237
# anthropologist	25	0.000220
# anthropologist	12	0.000149
# anthropology	12	0.000237
# anti	12	0.000237
# anti-authoritarian	12	0.000237
# anti-birth	12	0.000237
# anti-capitalism	12	0.000237
# anti-capitalist	12	0.000237
# anti-christian	12	0.000237
# anti-clearical	12	0.000237
# anti-clerical	12	0.000237
# anticonvulsants	25	0.000237
# antidepressants	25	0.000237
# anti-dogmatic	12	0.000237
# antifascist	12	0.000237
# anti-fascist	12	0.000237
# anti-globalisation	12	0.000237
# antimilitarism	12	0.000237
# anti-nuclear	12	0.000237
# anti-organizationalist	12	0.000237
# antipsychotics	25	0.000237
# anti-state	12	0.000237
# anti-statism	12	0.000237
# anti-syndicalist	12	0.000237
# anti-war	12	0.000237
# anti-worker	12	0.000237
# anxiety	25	0.000237
# apostles	12	0.000237
# apparent	25	0.000441
# apparent	12	0.000149
# appeal	12	0.000237
# appeals	12	0.000237
# appear	25	0.000237
# appeared	12	0.000237
# appears	25	0.000237
# applied	25	0.000237
# appliquee	12	0.000237
# approach	25	0.000237
# approaches	25	0.000661
# approaches	12	0.000149
# appropriateness	25	0.000237
# april	12	0.000237
# aragon	12	0.000237
# arbeter	12	0.000237
# arbitrary	25	0.000237
# archives	12	0.000237
# ardent	12	0.000237
# arditi	12	0.000237
# area	25	0.000237
# areas	25	0.000441
# areas	12	0.000149
# argentina	12	0.000237
# argentine	12	0.000237
# argue	25	0.000220
# argue	12	0.000149
# argued	12	0.000237
# argument	12	0.000237
# arguments	12	0.000237
# arises	25	0.000661
# arises	12	0.000149
# arkhē	12	0.000237
# arkhos	12	0.000237
# armaments	12	0.000237
# armand	12	0.000237
# arme	12	0.000237
# armed	12	0.000237
# army	12	0.000237
# arose	12	0.000237
# arranging	25	0.000237
# arrested	12	0.000237
# article	25	0.000237
# artists	12	0.000237
# artwork	12	0.000237
# ascribe	25	0.000237
# asd	25	0.000237
# asd-related	25	0.000237
# asds	25	0.000237
# asd's	25	0.000237
# ashgate	12	0.000237
# así	12	0.000237
# aside	25	0.000237
# asked	25	0.000237
# asleep	25	0.000237
# asociación	12	0.000237
# asociaciones	12	0.000237
# asociacionismo	12	0.000237
# aspects	25	0.000237
# asperger	25	0.000237
# asperger's	25	0.000237
# assassin	12	0.000237
# assassinated	12	0.000237
# assassinations	12	0.000237
# assassins	12	0.000237
# assess	25	0.000237
# assessing	25	0.000237
# assessment	25	0.000237
# assistons	12	0.000237
# associate	25	0.000237
# associated	25	0.003742
# associated	12	0.000149
# associates	12	0.000237
# association	25	0.000441
# association	12	0.000149
# associations	25	0.000220
# associations	12	0.000149
# associée	12	0.000237
# ateneo	12	0.000237
# attached	12	0.000237
# attachment	25	0.000237
# attachments	25	0.000237
# attack	12	0.000237
# attaining	12	0.000237
# attempt	12	0.000237
# attempted	12	0.000237
# attempts	12	0.000237
# attend	12	0.000237
# attention	25	0.001982
# attention	12	0.000149
# attitudes	12	0.000237
# attracted	12	0.000237
# attracting	12	0.000237
# attributable	25	0.000237
# atypical	25	0.000237
# atypically	25	0.000237
# au	12	0.000237
# audience	25	0.000237
# auditory	25	0.000237
# august	12	0.000237
# aujourd'hui	12	0.000237
# austrian	12	0.000237
# authentic	12	0.000237
# author	12	0.000237
# authorities	12	0.000237
# authority	12	0.000237
# authors	12	0.000237
# autism	25	0.000237
# autism.neither	25	0.000237
# autism's	25	0.000237
# autism/schizophrenia	25	0.000237
# autism-specific	25	0.000237
# autismus	25	0.000237
# autistic	25	0.000237
# autistic-like	25	0.000237
# autoantibodies	25	0.000237
# autonomist	12	0.000237
# autonomous	12	0.000237
# autonomy	25	0.000220
# autonomy	12	0.000149
# autós	25	0.000237
# availability	25	0.000237
# available	25	0.000237
# average	25	0.000237
# averages	25	0.000237
# aveyron	25	0.000237
# avoid	12	0.000237
# avoiding	25	0.000237
# awakenings	25	0.000237
# aware	25	0.000237
# awareness	25	0.000237
# away	12	0.000237
# b	12	0.000237
# babbling	25	0.000237
# baby	25	0.000237
# backed	12	0.000237
# background	25	0.000237
# baginski	12	0.000237
# bailie	12	0.000237
# baja	12	0.000237
# bakunin	12	0.000237
# bakunin's	12	0.000237
# balanced	25	0.000237
# bands	12	0.000237
# banging	25	0.000237
# bank	12	0.000237
# bao	12	0.000237
# barcelona	12	0.000237
# barclay	12	0.000237
# base	12	0.000237
# based	25	0.001321
# based	12	0.000149
# bases	25	0.000237
# basic	25	0.000661
# basic	12	0.000149
# basically	12	0.000237
# basis	25	0.000441
# basis	12	0.000149
# batchelder	12	0.000237
# battered	12	0.000237
# bavarian	12	0.000237
# bbc	12	0.000237
# bc	12	0.000237
# beck—and	12	0.000237
# began	12	0.000237
# begin	25	0.000237
# beginning	12	0.000237
# behavior	25	0.000237
# behavioral	25	0.000237
# behaviorautistic	25	0.000237
# behaviors	25	0.000237
# behavior.the	25	0.000237
# belief	25	0.000237
# beliefs	25	0.000220
# beliefs	12	0.000149
# believe	25	0.000441
# believe	12	0.000149
# believed	12	0.000237
# believing	25	0.000220
# believing	12	0.000149
# bellegarrigue	12	0.000237
# belongs	12	0.000237
# beneath	12	0.000237
# benefits	25	0.000237
# benjamin	12	0.000237
# benoît	12	0.000237
# berkman	12	0.000237
# berlin	12	0.000237
# berneri	12	0.000237
# best	25	0.000441
# best	12	0.000149
# best-known	12	0.000237
# bestseller	12	0.000237
# better	25	0.000237
# bewildering	25	0.000237
# bibliography	12	0.000237
# bien	12	0.000237
# biennio	12	0.000237
# big	25	0.000237
# bigger	12	0.000237
# biographies	12	0.000237
# biologically	25	0.000237
# birth	25	0.000661
# birth	12	0.000149
# bisexual	12	0.000237
# bisexuality	12	0.000237
# biting	25	0.000237
# bitter	12	0.000237
# black	12	0.000237
# blackshirts	12	0.000237
# blackwell	12	0.000237
# blair	25	0.000237
# blair's	25	0.000237
# blaming	25	0.000237
# blanquists	12	0.000237
# bleeding	25	0.000237
# bleed's	12	0.000237
# bleuler	25	0.000237
# bleuler's	25	0.000237
# blindisms	25	0.000237
# blindness	25	0.000237
# blockades	12	0.000237
# blocs	12	0.000237
# bob	12	0.000237
# body	25	0.000220
# body	12	0.000149
# boétie	12	0.000237
# bohemian	12	0.000237
# boldly	12	0.000237
# bologna	12	0.000237
# bolshevik	12	0.000237
# bolsheviks	12	0.000237
# bolshevism	12	0.000237
# bolten	12	0.000237
# bomb	12	0.000237
# bombers	12	0.000237
# bombings	12	0.000237
# bones	25	0.000237
# bonnot	12	0.000237
# book	12	0.000237
# bookchin	12	0.000237
# booklets	12	0.000237
# books	12	0.000237
# borgue	25	0.000237
# born	25	0.000237
# bosses	12	0.000237
# boston	12	0.000237
# botched	25	0.000237
# bottomore	12	0.000237
# boundaries	25	0.000237
# bourgeois	12	0.000237
# boy	25	0.000237
# boys	25	0.000237
# bragg	12	0.000237
# brain	25	0.000237
# brain—but	25	0.000237
# brain-imaging	25	0.000237
# brains	25	0.000237
# brain's	25	0.000237
# brainwave	25	0.000237
# branch	12	0.000237
# brand	12	0.000237
# brandenburg	12	0.000237
# brazil	12	0.000237
# breton	12	0.000237
# brian	12	0.000237
# brief	12	0.000237
# briefly	12	0.000237
# bring	12	0.000237
# britain	12	0.000237
# britannica	12	0.000237
# british	25	0.000220
# british	12	0.000149
# broadband	25	0.000237
# broader	25	0.000237
# broadly	12	0.000237
# broadview	12	0.000237
# broke	12	0.000237
# brominated	25	0.000237
# brother	25	0.000237
# broutchoux	12	0.000237
# brunella	12	0.000237
# bryan	12	0.000237
# bufe	12	0.000237
# build	12	0.000237
# bulgarian	12	0.000237
# burden	25	0.000237
# burglars	12	0.000237
# burke	12	0.000237
# business	12	0.000237
# butterfly	12	0.000237
# bypass	25	0.000237
# cadres	12	0.000237
# california	12	0.000237
# called	25	0.000661
# called	12	0.000149
# calls	12	0.000237
# camaraderie	12	0.000237
# camden	12	0.000237
# came	12	0.000237
# camillo	12	0.000237
# camp	12	0.000237
# campaign	12	0.000237
# campaigned	12	0.000237
# campaigners	12	0.000237
# camps	12	0.000237
# camus	12	0.000237
# canada	12	0.000237
# canadian	25	0.000237
# candidate	25	0.000237
# canon	12	0.000237
# capacity	12	0.000237
# capitalism	12	0.000237
# capitalist	12	0.000237
# capitalistic	12	0.000237
# caplan	12	0.000237
# cappelli	12	0.000237
# care	25	0.000237
# caregiver	25	0.000237
# caregivers	25	0.000237
# carl	12	0.000237
# carrara	12	0.000237
# carried	12	0.000237
# carry	25	0.000237
# cars	25	0.000237
# carter	12	0.000237
# casa	12	0.000237
# casali	12	0.000237
# cascade	25	0.000237
# case	25	0.000237
# casein-free	25	0.000237
# cases	25	0.000237
# cast	25	0.000237
# catalan	12	0.000237
# catalonia	12	0.000237
# categories	25	0.000441
# categories	12	0.000149
# categorizes	25	0.000237
# category	25	0.000237
# catholic	12	0.000237
# cathy	12	0.000237
# caught	25	0.000237
# causal	25	0.000237
# cause	25	0.002201
# cause	12	0.000149
# caused	25	0.000237
# causes	25	0.000237
# causing	25	0.000220
# causing	12	0.000149
# cdc	25	0.000237
# ce	12	0.000237
# celebration	12	0.000237
# celebrities	12	0.000237
# cell	25	0.000237
# cell-adhesion	25	0.000237
# cells	25	0.000237
# cellular	25	0.000237
# center	12	0.000237
# centers	25	0.000237
# central	25	0.000441
# central	12	0.000149
# centralisation	12	0.000237
# centralist	12	0.000237
# centrality	12	0.000237
# centre	12	0.000237
# centuries	12	0.000237
# century	12	0.000237
# certain	25	0.000220
# certain	12	0.000149
# cgt	12	0.000237
# challenge	25	0.000237
# change	25	0.000441
# change	12	0.000149
# changed	12	0.000237
# changes	25	0.000237
# changing	25	0.000237
# characterised	12	0.000237
# characteristic	25	0.000237
# characteristics	25	0.000220
# characteristics	12	0.000149
# characteristicsautism	25	0.000237
# characterized	25	0.000237
# characters	12	0.000237
# charged	12	0.000237
# charges	12	0.000237
# charles	12	0.000237
# charters	12	0.000237
# chasm	12	0.000237
# chat	25	0.000237
# checklist	25	0.000237
# chelation	25	0.000237
# chernyi	12	0.000237
# chicago	12	0.000237
# chicago's	12	0.000237
# chicken	12	0.000237
# child	25	0.000237
# childhood	25	0.000237
# child-led	12	0.000237
# children	25	0.014308
# children	12	0.000149
# children's	25	0.000237
# child's	25	0.000661
# child's	12	0.000149
# chile	12	0.000237
# china	12	0.000237
# choice	12	0.000237
# christ	12	0.000237
# christiaan	12	0.000237
# christian	12	0.000237
# christiania	12	0.000237
# christianity	12	0.000237
# chromosome	25	0.000237
# chromosomes	25	0.000237
# chronological	12	0.000237
# church	12	0.000237
# cingulate	25	0.000237
# circuit	25	0.000237
# circuits	25	0.000237
# cite	12	0.000237
# cited	12	0.000237
# citing	12	0.000237
# citium	12	0.000237
# citizens	12	0.000237
# city	12	0.000237
# city's	12	0.000237
# civil	12	0.000237
# civilization	12	0.000237
# claim	25	0.000237
# claimed	25	0.000220
# claimed	12	0.000149
# claiming	12	0.000237
# claims	25	0.000237
# class	12	0.000237
# classe	12	0.000237
# classes	25	0.000237
# classic	25	0.000220
# classic	12	0.000149
# classical	12	0.000237
# classification	25	0.000237
# classificationautism	25	0.000237
# classifications	12	0.000237
# classify	25	0.000237
# clear	25	0.000441
# clear	12	0.000149
# clearly	12	0.000237
# cleyre	12	0.000237
# clifford	12	0.000237
# climate	12	0.000237
# climaxed	12	0.000237
# clinical	25	0.000237
# close	25	0.000441
# close	12	0.000149
# closely	25	0.000237
# closeness	25	0.000237
# closer	12	0.000237
# closest	25	0.000237
# cnrs	12	0.000237
# cnt	12	0.000237
# c.n.t	12	0.000237
# cnt-ait	12	0.000237
# co-editor	12	0.000237
# coercion	12	0.000237
# coercive	12	0.000237
# coeurderoy	12	0.000237
# coexisting	25	0.000237
# cognition	25	0.000237
# cognitive	25	0.000237
# cognitively	25	0.000237
# coherence	25	0.000237
# cohesive	12	0.000237
# coined	25	0.000237
# cold	12	0.000237
# colin	12	0.000237
# collaborated	12	0.000237
# collection	12	0.000237
# collective	12	0.000237
# collectives	12	0.000237
# collectivise	12	0.000237
# collectivised	12	0.000237
# collectivism	12	0.000237
# collectivist	12	0.000237
# collectivists	12	0.000237
# collectivization	12	0.000237
# colonies	12	0.000237
# combination	25	0.000237
# combinations	25	0.000237
# combine	12	0.000237
# combined	25	0.000220
# combined	12	0.000149
# combines	12	0.000237
# combining	25	0.000220
# combining	12	0.000149
# comfort	12	0.000237
# comment	25	0.000237
# commercial	25	0.000237
# committed	25	0.000220
# committed	12	0.000149
# committee	12	0.000237
# committees	12	0.000237
# committing	12	0.000237
# common	25	0.003302
# common	12	0.000149
# commonly	25	0.000880
# commonly	12	0.000149
# communal	12	0.000237
# communards	12	0.000237
# commune	12	0.000237
# communes	12	0.000237
# communicate	25	0.000237
# communicated	25	0.000237
# communication	25	0.000237
# communicationabout	25	0.000237
# communism	12	0.000237
# communist	12	0.000237
# communists	12	0.000237
# communities	25	0.000220
# communities	12	0.000149
# community	25	0.000237
# comorbid	25	0.000237
# companion	12	0.000237
# compared	25	0.000237
# comparison	25	0.000237
# compatibility	12	0.000237
# compatible	12	0.000237
# compensation	12	0.000237
# compiled	25	0.000237
# complete	12	0.000237
# completed	25	0.000237
# completely	25	0.000237
# complex	25	0.001100
# complex	12	0.000149
# complexity	25	0.000237
# component	12	0.000237
# composizione	12	0.000237
# comprehends	25	0.000237
# comprehension	25	0.000237
# compris	12	0.000237
# compromise	12	0.000237
# compulsion	12	0.000237
# compulsive	25	0.000237
# compulsory	12	0.000237
# comstockery"—censorship	12	0.000237
# conceived	12	0.000237
# concentrated	12	0.000237
# concentration	12	0.000237
# concept	12	0.000237
# conception	25	0.000237
# conceptions	12	0.000237
# concepts	12	0.000237
# conceptual	12	0.000237
# concern	25	0.000441
# concern	12	0.000149
# concerned	12	0.000237
# concerning	12	0.000237
# concerns	12	0.000237
# concise	12	0.000237
# concluded	12	0.000237
# conclusion	12	0.000237
# conclusions	25	0.000237
# concur	12	0.000237
# concurrent	25	0.000237
# condition	25	0.000220
# condition	12	0.000149
# conditioned	12	0.000237
# conditions	25	0.001761
# conditions	12	0.000149
# conducive	12	0.000237
# conduct	12	0.000237
# conducted	25	0.000237
# confederación	12	0.000237
# confederation	12	0.000237
# conference	12	0.000237
# confines	12	0.000237
# confirmed	25	0.000237
# conflict	25	0.000220
# conflict	12	0.000149
# conflict.in	12	0.000237
# conflicting	25	0.000237
# conflicts	12	0.000237
# confluirá	12	0.000237
# confrontations	12	0.000237
# confused	25	0.000237
# congenital	25	0.000237
# congress	12	0.000237
# congresses	12	0.000237
# connect	25	0.000237
# connections	25	0.000237
# connectivity	25	0.000237
# connotation	12	0.000237
# conquered	12	0.000237
# conquest	12	0.000237
# conscience	12	0.000237
# conscience."mini-manual	12	0.000237
# conscious	12	0.000237
# consensus	25	0.000237
# consenting	12	0.000237
# consequences	12	0.000237
# consequently	12	0.000237
# conservateur	12	0.000237
# conservative	12	0.000237
# consider	25	0.000220
# consider	12	0.000149
# considerable	25	0.000441
# considerable	12	0.000149
# considered	25	0.000441
# considered	12	0.000149
# considering	25	0.000237
# consistent	25	0.000220
# consistent	12	0.000149
# consistently	25	0.000237
# consists	12	0.000237
# consonants	25	0.000237
# constituted	12	0.000237
# constructors	12	0.000237
# consumer	12	0.000237
# consumption	12	0.000237
# contact	25	0.000237
# containing	12	0.000237
# contains	25	0.000237
# contemporaneously	12	0.000237
# contemporary	12	0.000237
# context	12	0.000237
# contexts	25	0.000237
# continually	12	0.000237
# continue	25	0.000237
# continued	12	0.000237
# continues	12	0.000237
# continuing	25	0.000237
# continuous	25	0.000237
# continuum	25	0.000237
# contract	12	0.000237
# contradict	25	0.000237
# contradiction	12	0.000237
# contrast	25	0.000220
# contrast	12	0.000149
# contrasted	12	0.000237
# contribute	25	0.000237
# contributed	12	0.000237
# contributors	12	0.000237
# control	25	0.000220
# control	12	0.000149
# controlled	25	0.000220
# controlled	12	0.000149
# controls	25	0.000237
# controversial	25	0.000237
# controversies	25	0.000237
# converging	25	0.000237
# conversely	25	0.000237
# convincing	25	0.000237
# co-occur	25	0.000237
# cooperation	12	0.000237
# cooperatives	12	0.000237
# coordination	25	0.000237
# copenhagen.since	12	0.000237
# copy	25	0.000237
# core	25	0.000237
# cornelissen	12	0.000237
# corps	12	0.000237
# corpse	12	0.000237
# correlated	25	0.000237
# correlation	25	0.000237
# cortex	25	0.000237
# cost	25	0.000441
# cost	12	0.000149
# costs	25	0.000237
# council	12	0.000237
# councilist	12	0.000237
# councils	12	0.000237
# council's	12	0.000237
# counterculture	12	0.000237
# counter-economics	12	0.000237
# counterparts	12	0.000237
# counter-revolution	12	0.000237
# counter-revolutionaries	12	0.000237
# countries	25	0.000220
# countries	12	0.000149
# country	12	0.000237
# coup	12	0.000237
# course	25	0.000237
# court	25	0.000237
# cover	25	0.000237
# craft	12	0.000237
# crass	12	0.000237
# create	12	0.000237
# created	12	0.000237
# creates	12	0.000237
# creating	12	0.000237
# creation	12	0.000237
# creative	12	0.000237
# credit	12	0.000237
# credits	12	0.000237
# crimes	25	0.000237
# crisis	12	0.000237
# critchley	12	0.000237
# criteria	25	0.000237
# critic	25	0.000220
# critic	12	0.000149
# critical	25	0.000220
# critical	12	0.000149
# criticised	12	0.000237
# criticisms	12	0.000237
# criticize	12	0.000237
# criticized	12	0.000237
# criticizes	12	0.000237
# criticizing	12	0.000237
# critique	12	0.000237
# critiqued	12	0.000237
# cross	12	0.000237
# crowd	12	0.000237
# crucial	25	0.000237
# crushed	12	0.000237
# cryptography	12	0.000237
# cuales	12	0.000237
# cuba	12	0.000237
# cuban	12	0.000237
# cues	25	0.000237
# culminated	12	0.000237
# cultural	25	0.000237
# cultural-critical	12	0.000237
# culture	25	0.000441
# culture	12	0.000149
# culture's	25	0.000237
# cura	12	0.000237
# cure	25	0.000237
# currency	12	0.000237
# current	25	0.000220
# current	12	0.000149
# currents	12	0.000237
# cynics	12	0.000237
# cyréaniques	12	0.000237
# czolgosz	12	0.000237
# daily	25	0.000880
# daily	12	0.000149
# dalla	12	0.000237
# damage	12	0.000237
# daniel	12	0.000237
# dans	12	0.000237
# d'antan	12	0.000237
# data	25	0.000237
# date	12	0.000237
# david	12	0.000237
# day	12	0.000237
# day.propaganda	12	0.000237
# deal	25	0.000237
# dealing	12	0.000237
# deaths	25	0.000237
# debate	25	0.000220
# debate	12	0.000149
# debates	12	0.000237
# début	12	0.000237
# decades	25	0.000237
# deceased	12	0.000237
# december	12	0.000237
# decentralised	12	0.000237
# decide	12	0.000237
# decided	12	0.000237
# decisions	12	0.000237
# declared	12	0.000237
# decline	25	0.000237
# decrease	25	0.000237
# dedicated	12	0.000237
# deed	12	0.000237
# deeply	25	0.000237
# default	25	0.000237
# defeated	12	0.000237
# defects	25	0.000237
# defend—through	12	0.000237
# defense	12	0.000237
# defiance	12	0.000237
# deficiency	25	0.000237
# deficit	25	0.000237
# deficits	25	0.000237
# define	12	0.000237
# defined	25	0.000441
# defined	12	0.000149
# defining	25	0.000237
# definition	25	0.000237
# definitional	12	0.000237
# definitive	25	0.000237
# degree	12	0.000237
# degrees	25	0.000220
# degrees	12	0.000149
# déjacque	12	0.000237
# del	12	0.000237
# delay	25	0.000237
# delayed	25	0.000237
# delays	25	0.000237
# delegate	12	0.000237
# delegates	12	0.000237
# deletion	25	0.000237
# deletions	25	0.000237
# demand	12	0.000237
# demanded	12	0.000237
# demanding	12	0.000237
# democracy	12	0.000237
# democratic	12	0.000237
# democratically	12	0.000237
# democrats.due	12	0.000237
# demonstrated	25	0.000237
# demonstrating	25	0.000237
# dendritic	25	0.000237
# denmark	12	0.000237
# denouncing	12	0.000237
# depend	25	0.000237
# depending	25	0.000237
# depends	25	0.000237
# depression	25	0.000237
# deprivation	25	0.000237
# deprived	12	0.000237
# der	12	0.000237
# derived	25	0.000237
# derives	12	0.000237
# deschooling	12	0.000237
# described	25	0.000880
# described	12	0.000149
# describes	25	0.000237
# describing	12	0.000237
# desde	12	0.000237
# designed	25	0.000237
# desire	12	0.000237
# desperation	12	0.000237
# despite	25	0.000220
# despite	12	0.000149
# destacada	12	0.000237
# destacados	12	0.000237
# destigmatization	25	0.000237
# destroyed	12	0.000237
# destruction	25	0.000220
# destruction	12	0.000149
# detailed	25	0.000237
# detailing	12	0.000237
# detection	25	0.000237
# determinants	12	0.000237
# determination	12	0.000237
# determined	12	0.000237
# detroit-based	12	0.000237
# develop	25	0.000880
# develop	12	0.000149
# developed	25	0.000880
# developed	12	0.000149
# developing	25	0.000237
# development	25	0.002642
# development	12	0.000149
# developmental	25	0.000237
# developmentsocial	25	0.000237
# devil	25	0.000237
# di	12	0.000237
# diabetes	25	0.000237
# diagnose	25	0.000237
# diagnosed	25	0.000237
# diagnoses	25	0.000237
# diagnosis	25	0.000237
# diagnosisdiagnosis	25	0.000237
# diagnostic	25	0.000237
# dictadura	12	0.000237
# dictatorship	12	0.000237
# dictionary	12	0.000237
# did	25	0.000220
# did	12	0.000149
# die	12	0.000237
# died	12	0.000237
# dielo	12	0.000237
# diesel	25	0.000237
# diets	25	0.000237
# díez	12	0.000237
# diferentes	12	0.000237
# differ	25	0.000441
# differ	12	0.000149
# difference	25	0.000441
# difference	12	0.000149
# differences	25	0.000237
# different	25	0.000441
# different	12	0.000149
# differential	25	0.000237
# differentiate	25	0.000237
# differently	25	0.000237
# differs	25	0.000237
# difficult	25	0.000237
# difficulties	25	0.000237
# difficulty	25	0.000237
# diffusion	25	0.000237
# diggers	12	0.000237
# diminished	25	0.000237
# diogenes	12	0.000237
# direct	12	0.000237
# directed	12	0.000237
# directing	25	0.000237
# direction	12	0.000237
# directly	12	0.000237
# disability	25	0.000237
# disabled	25	0.000237
# disagreement	12	0.000237
# disappearance	12	0.000237
# disappears	25	0.000237
# disarmament	12	0.000237
# discharged	25	0.000237
# disciplines	25	0.000237
# discount	12	0.000237
# discours	12	0.000237
# discourse	12	0.000237
# discriminated	12	0.000237
# discussion	12	0.000237
# disease	25	0.000237
# diseases	25	0.000237
# disenfranchisment	12	0.000237
# disintegrative	25	0.000237
# dismemberment	12	0.000237
# disobedience	12	0.000237
# disorder	25	0.000237
# disorders	25	0.000237
# disparate	12	0.000237
# display	25	0.000237
# disproven.parents	25	0.000237
# disputed	12	0.000237
# disputes	12	0.000237
# disrupted	25	0.000237
# disrupting	25	0.000237
# dissident	12	0.000237
# dissolution	12	0.000237
# distanced	12	0.000237
# distinct	25	0.000237
# distinction	25	0.000220
# distinction	12	0.000149
# distinctly	25	0.000237
# distinguish	25	0.000237
# distinguished	25	0.000220
# distinguished	12	0.000149
# distinguishing	25	0.000237
# distortion	25	0.000237
# distress	25	0.000237
# distributed	12	0.000237
# distribution	12	0.000237
# district	12	0.000237
# districts	12	0.000237
# disturb	25	0.000237
# disturbance	25	0.000237
# disturbances	25	0.000237
# disturbed	25	0.000237
# disused	12	0.000237
# diverse	25	0.000441
# diverse	12	0.000149
# diversity	12	0.000237
# diversos	12	0.000237
# divided	25	0.000661
# divided	12	0.000149
# divine	12	0.000237
# dna	25	0.000237
# doctors	25	0.000237
# doctrine	12	0.000237
# doctrines	12	0.000237
# doctrines.phenomena	12	0.000237
# document	12	0.000237
# documentary	12	0.000237
# documented	12	0.000237
# documents	12	0.000237
# does	25	0.001541
# does	12	0.000149
# dogma	12	0.000237
# doing	25	0.000237
# dolgoff	12	0.000237
# dollars	25	0.000237
# domination	12	0.000237
# dommage	12	0.000237
# dorothy	12	0.000237
# doubt	25	0.000237
# doug	12	0.000237
# draft	12	0.000237
# dramatically	25	0.000237
# drawing	12	0.000237
# draws	12	0.000237
# dressing	25	0.000237
# drew	12	0.000237
# driven	12	0.000237
# drug	25	0.000237
# drugs	25	0.000237
# dsm-iv	25	0.000237
# dsm-iv-tr	25	0.000237
# du	12	0.000237
# dual	12	0.000237
# duplications	25	0.000237
# durante	12	0.000237
# dwarfed	12	0.000237
# dwight	12	0.000237
# dynamite	12	0.000237
# dynamiter	12	0.000237
# dysfunction	25	0.000237
# dysfunctional	12	0.000237
# dysmorphic	25	0.000237
# e	12	0.000237
# earlier	25	0.000237
# earliest	25	0.000220
# earliest	12	0.000149
# early	25	0.003302
# early	12	0.000149
# earth	12	0.000237
# eastern	12	0.000237
# eating	25	0.000237
# e.c	12	0.000237
# echolalia	25	0.000237
# echolalic	25	0.000237
# eclectic	12	0.000237
# ecléctico	12	0.000237
# eco-anarchism	12	0.000237
# ecole	12	0.000237
# ecological	12	0.000237
# ecology.anarcho-pacifism	12	0.000237
# economic	25	0.000220
# economic	12	0.000149
# economical	12	0.000237
# economics	12	0.000237
# economy	12	0.000237
# ed	12	0.000237
# edited	12	0.000237
# editor	12	0.000237
# edmund	12	0.000237
# edna	12	0.000237
# educate	12	0.000237
# education	25	0.001100
# education	12	0.000149
# educational	25	0.000661
# educational	12	0.000149
# educator	12	0.000237
# educators	25	0.000237
# edward	12	0.000237
# effacé	12	0.000237
# effective	25	0.000237
# effectively	12	0.000237
# effectiveness	25	0.000237
# effects	25	0.000237
# efficacy	25	0.000237
# effort	12	0.000237
# efforts	12	0.000237
# e.g	12	0.000237
# egg	12	0.000237
# ego	12	0.000237
# egoism	12	0.000237
# egoist	12	0.000237
# egoists	12	0.000237
# eigenheit	12	0.000237
# eight-hour	12	0.000237
# el	12	0.000237
# elaborate	25	0.000237
# electing	12	0.000237
# election	12	0.000237
# electoral	12	0.000237
# electrical	25	0.000237
# elements	12	0.000237
# elevated	25	0.000237
# eliminate	12	0.000237
# eliminated	12	0.000237
# elimination	12	0.000237
# elite	12	0.000237
# ellul.platformism	12	0.000237
# emancipación	12	0.000237
# embodied	25	0.000237
# embodies	12	0.000237
# embrace	12	0.000237
# embraced	12	0.000237
# embryonic	25	0.000237
# emerge	25	0.000237
# emerged	12	0.000237
# emergence	12	0.000237
# emerges	12	0.000237
# emile	12	0.000237
# emma	12	0.000237
# emotion	25	0.000237
# emotional	25	0.000237
# emotions	25	0.000237
# empathizing	25	0.000237
# empathizing–systemizing	25	0.000237
# emphasise	12	0.000237
# emphasises	12	0.000237
# emphasize	12	0.000237
# emphasizes	12	0.000237
# emphatically	12	0.000237
# empirical	25	0.000237
# employed	25	0.000237
# employers	25	0.000237
# employment	25	0.000441
# employment	12	0.000149
# en	12	0.000237
# enabling	25	0.000237
# enactment	12	0.000237
# encarta	12	0.000237
# encounter	12	0.000237
# encouraged	12	0.000237
# encyclopædia	12	0.000237
# encyclopedia	12	0.000237
# end	12	0.000237
# ended	12	0.000237
# ends	12	0.000237
# endured	12	0.000237
# enemies	12	0.000237
# enemy	12	0.000237
# engaged	12	0.000237
# england	12	0.000237
# english	25	0.000441
# english	12	0.000149
# english-language	12	0.000237
# enhancing	25	0.000237
# enjoyment	12	0.000237
# enjoys	12	0.000237
# enlightened	12	0.000237
# enlightenment	12	0.000237
# enragés	12	0.000237
# enslaved	12	0.000237
# ensuing	12	0.000237
# entails	12	0.000237
# entered	12	0.000237
# enthusiastic	12	0.000237
# entitlement	12	0.000237
# entries	12	0.000237
# entry	12	0.000237
# environment	25	0.000237
# environmental	25	0.001321
# environmental	12	0.000149
# environments	25	0.000237
# epidemiology	25	0.000237
# epigenetic	25	0.000237
# epilepsy	25	0.000237
# epistemologie	12	0.000237
# equality	12	0.000237
# equally	25	0.000237
# equals	12	0.000237
# equivalent	12	0.000237
# erich	12	0.000237
# ernest	12	0.000237
# érotique	12	0.000237
# errico	12	0.000237
# errors	25	0.000237
# escape	12	0.000237
# escuela	12	0.000237
# español	12	0.000237
# especial	12	0.000237
# especially	12	0.000237
# especie	12	0.000237
# esperantismo	12	0.000237
# espouse	12	0.000237
# essay	12	0.000237
# essence).""anarchisme	12	0.000237
# essential	25	0.000237
# essentially	25	0.000220
# essentially	12	0.000149
# est	12	0.000237
# esta	12	0.000237
# established	25	0.000441
# established	12	0.000149
# establishment	12	0.000237
# estate	25	0.000220
# estate	12	0.000149
# estimate	25	0.000237
# estimated	25	0.001100
# estimated	12	0.000149
# et	12	0.000237
# eternal	12	0.000237
# ethical	25	0.000220
# ethical	12	0.000149
# ethnicity	25	0.000237
# ética	12	0.000237
# étienne	12	0.000237
# etymology	12	0.000237
# eugen	25	0.000237
# eunice	12	0.000237
# europe	12	0.000237
# european	12	0.000237
# evaluations	25	0.000237
# event	12	0.000237
# event-related	25	0.000237
# events	25	0.000661
# events	12	0.000149
# eventually	12	0.000237
# everybody	12	0.000237
# evidence	25	0.000237
# evil	12	0.000237
# evolution	12	0.000237
# exacerbate	25	0.000237
# exact	12	0.000237
# examining	25	0.000237
# example	25	0.002421
# example	12	0.000149
# examples	25	0.000220
# examples	12	0.000149
# excellent	12	0.000237
# excess	25	0.000237
# exchangeable	12	0.000237
# excitatory–inhibitory	25	0.000237
# exclude	25	0.000237
# excludes	25	0.000237
# exclusive	12	0.000237
# exclusively	12	0.000237
# excursionismo	12	0.000237
# excursionista	12	0.000237
# excuse	12	0.000237
# executed	12	0.000237
# execution	12	0.000237
# executive	25	0.000237
# exemplary	12	0.000237
# exemplified	12	0.000237
# exercised	12	0.000237
# exhaust	25	0.000237
# exhibit	25	0.000237
# exhibited	12	0.000237
# exhibiting	25	0.000237
# exile	12	0.000237
# exiles	12	0.000237
# exist	12	0.000237
# existed	12	0.000237
# existence	12	0.000237
# existing	12	0.000237
# expanded	12	0.000237
# expansion	25	0.000237
# expelled	12	0.000237
# expense	12	0.000237
# expenses	25	0.000237
# expensive	25	0.000237
# experience	25	0.000220
# experience	12	0.000149
# experienced	12	0.000237
# experiences	25	0.000220
# experiences	12	0.000149
# experimental	12	0.000237
# experiments	25	0.000220
# experiments	12	0.000149
# explain	25	0.000441
# explain	12	0.000149
# explained	25	0.000237
# explaining	25	0.000220
# explaining	12	0.000149
# explanations	25	0.000237
# expound	12	0.000237
# expounded	12	0.000237
# express	25	0.000237
# expressed	12	0.000237
# expression	25	0.000220
# expression	12	0.000149
# expropriation	12	0.000237
# expropriations	12	0.000237
# extended	12	0.000237
# extension	25	0.000237
# extensive	25	0.000237
# extent	25	0.000441
# extent	12	0.000149
# external	25	0.000220
# external	12	0.000149
# extra	25	0.000237
# extraordinarily	25	0.000237
# extreme	25	0.000441
# extreme	12	0.000149
# eye	25	0.000237
# ezra	12	0.000237
# fabbri	12	0.000237
# face	25	0.000237
# facial	25	0.000237
# facilities	25	0.000237
# facing	12	0.000237
# fact	12	0.000237
# factions	12	0.000237
# factor	25	0.000237
# factories	12	0.000237
# factors	25	0.000237
# factory	12	0.000237
# fail	25	0.000237
# fails	25	0.000237
# failure	25	0.000441
# failure	12	0.000149
# failures	12	0.000237
# fair	25	0.000237
# falling	25	0.000220
# falling	12	0.000149
# fall-winter	12	0.000237
# false	12	0.000237
# false-negatives	25	0.000237
# false-positives	25	0.000237
# families	25	0.000237
# family	25	0.001541
# family	12	0.000149
# famous	12	0.000237
# fantasies	25	0.000237
# faq	12	0.000237
# far	25	0.000220
# far	12	0.000149
# fascism	12	0.000237
# fascismo	12	0.000237
# fascist	12	0.000237
# fascists	12	0.000237
# faster	25	0.000237
# fathers	25	0.000237
# faure	12	0.000237
# favor	12	0.000237
# favored	12	0.000237
# features	25	0.000237
# february	12	0.000237
# federación	12	0.000237
# federal	12	0.000237
# federalist	12	0.000237
# federation	12	0.000237
# fédération	12	0.000237
# federations	12	0.000237
# federazione	12	0.000237
# feel	25	0.000237
# feeling	25	0.000237
# femelle	12	0.000237
# feminism	12	0.000237
# feminist	12	0.000237
# feminists	12	0.000237
# feral	25	0.000237
# fernand	12	0.000237
# fernandez	12	0.000237
# fernando	12	0.000237
# ferrer	12	0.000237
# ferrer's	12	0.000237
# field	12	0.000237
# fiercely	12	0.000237
# fifth	12	0.000237
# fight	12	0.000237
# figurative	25	0.000237
# figure	12	0.000237
# figureheads	12	0.000237
# figures	12	0.000237
# film	12	0.000237
# films	12	0.000237
# final	25	0.000220
# final	12	0.000149
# finally	12	0.000237
# financial	25	0.000237
# findings	25	0.000237
# firebrand	12	0.000237
# firm	25	0.000237
# firmly	12	0.000237
# five-year-old	25	0.000237
# fixed	12	0.000237
# flame	25	0.000237
# flapping	25	0.000237
# fled	12	0.000237
# flesh	25	0.000237
# flores	12	0.000237
# flowing	12	0.000237
# flows	12	0.000237
# fluctuations	12	0.000237
# fluxing	12	0.000237
# fmri	25	0.000237
# focus	25	0.001100
# focus	12	0.000149
# focused	25	0.000237
# focuses	25	0.000441
# focuses	12	0.000149
# follow	25	0.000237
# followed	25	0.000220
# followed	12	0.000149
# followers	12	0.000237
# following	25	0.000441
# following	12	0.000149
# follows	25	0.000237
# fontana/collins	12	0.000237
# food	25	0.000237
# foods	25	0.000237
# force	12	0.000237
# forced	12	0.000237
# forces	12	0.000237
# forcibly	12	0.000237
# foresaw	12	0.000237
# form	25	0.001100
# form	12	0.000149
# formal	25	0.000441
# formal	12	0.000149
# formally	12	0.000237
# formation	25	0.000220
# formation	12	0.000149
# formed	12	0.000237
# forms	25	0.000661
# forms	12	0.000149
# formulate	12	0.000237
# formulated	12	0.000237
# forum	12	0.000237
# forward	12	0.000237
# foster	12	0.000237
# fotlu	12	0.000237
# fought	12	0.000237
# founded	12	0.000237
# founder	12	0.000237
# founding	12	0.000237
# four-fifths	25	0.000237
# four-page	12	0.000237
# fraction	25	0.000237
# fragile	25	0.000237
# fragility	25	0.000237
# fragments	12	0.000237
# france	12	0.000237
# france.anarchism	12	0.000237
# france's	12	0.000237
# francesc	12	0.000237
# francisco	12	0.000237
# franco	12	0.000237
# franco-prussian	12	0.000237
# frank	12	0.000237
# fraud	25	0.000237
# fraye	12	0.000237
# free	12	0.000237
# freedom	12	0.000237
# free-market	12	0.000237
# free-thinker	12	0.000237
# freethinkers	12	0.000237
# freethought	12	0.000237
# free-thought	12	0.000237
# freetown	12	0.000237
# freie	12	0.000237
# french	12	0.000237
# frequent	25	0.000237
# frequented	12	0.000237
# friends	25	0.000237
# friendships	25	0.000237
# frontal	25	0.000237
# fruits	12	0.000237
# fulfill	12	0.000237
# fulfillment	12	0.000237
# fully	12	0.000237
# function	25	0.000237
# functional	25	0.000237
# functioning	25	0.000237
# functioning—focuses	25	0.000237
# functions	25	0.000237
# fundamental	12	0.000237
# fundamentally	12	0.000237
# funded	25	0.000237
# funding	25	0.000237
# furniture	25	0.000237
# fused	12	0.000237
# fusiform	25	0.000237
# future	25	0.000661
# future	12	0.000149
# gain	25	0.000237
# gained	12	0.000237
# galleani's	12	0.000237
# game	25	0.000237
# gang	12	0.000237
# gap	25	0.000237
# gastrointestinal	25	0.000237
# gathered	12	0.000237
# gay	12	0.000237
# gender	12	0.000237
# gene	25	0.000237
# general	25	0.001100
# general	12	0.000149
# generalized	25	0.000237
# generally	25	0.001100
# generally	12	0.000149
# generate	12	0.000237
# generated	25	0.000237
# generation	12	0.000237
# generations	12	0.000237
# genes	25	0.000237
# genetic	25	0.000237
# geneticists	25	0.000237
# genetics	25	0.000237
# genome	25	0.000237
# genome's	25	0.000237
# genotype-first	25	0.000237
# genuine	12	0.000237
# geoffrey	12	0.000237
# geofrey	12	0.000237
# george	12	0.000237
# georges	12	0.000237
# german	25	0.000220
# german	12	0.000149
# germany	12	0.000237
# gerrard	12	0.000237
# gesell	12	0.000237
# gesellschaft	12	0.000237
# gestation	25	0.000237
# gestures	25	0.000237
# gesturing	25	0.000237
# gi	25	0.000237
# gimenez	12	0.000237
# ginsberg	12	0.000237
# girls	25	0.000237
# given	25	0.000237
# global	25	0.000220
# global	12	0.000149
# globally	12	0.000237
# glorification	12	0.000237
# glutamate	25	0.000237
# goal	25	0.000220
# goal	12	0.000149
# goal-directed	25	0.000237
# goals	25	0.000237
# god	12	0.000237
# godwin	12	0.000237
# goebbels	12	0.000237
# goes	12	0.000237
# goldman	12	0.000237
# good	25	0.000880
# good	12	0.000149
# goodman	12	0.000237
# goods	12	0.000237
# goodway	12	0.000237
# gordon	12	0.000237
# governance	12	0.000237
# governed	12	0.000237
# government	12	0.000237
# government-subsidized	25	0.000237
# governors	12	0.000237
# gradual	12	0.000237
# gradually	25	0.000237
# graeber	12	0.000237
# graham	12	0.000237
# graham's	12	0.000237
# grandin	25	0.000237
# granted	25	0.000237
# graphic	12	0.000237
# great	12	0.000237
# greater	25	0.000237
# greatest	12	0.000237
# greatly	25	0.000237
# greek	25	0.000220
# greek	12	0.000149
# green	12	0.000237
# greene	12	0.000237
# greenwich	12	0.000237
# grew	12	0.000237
# ground	12	0.000237
# group	25	0.000220
# group	12	0.000149
# grouped	12	0.000237
# grouping	12	0.000237
# groups	25	0.000220
# groups	12	0.000149
# grow	25	0.000237
# growth	25	0.000237
# grubacic	12	0.000237
# grupo	12	0.000237
# grupos	12	0.000237
# guàrdia	12	0.000237
# guards	12	0.000237
# guerin	12	0.000237
# guide	12	0.000237
# guidelines	25	0.000237
# guiding	12	0.000237
# guillaume	12	0.000237
# gunmen	12	0.000237
# gustav	12	0.000237
# habits	12	0.000237
# hague	12	0.000237
# half	25	0.000237
# hampered	25	0.000237
# han	12	0.000237
# hand	25	0.000880
# hand	12	0.000149
# handbook	12	0.000237
# handle	25	0.000237
# handled	25	0.000237
# handling	25	0.000237
# hand."[[max	12	0.000237
# hanging	12	0.000237
# hans	25	0.000237
# happens	25	0.000237
# happiness	12	0.000237
# harassment	12	0.000237
# hard	25	0.000237
# harder	25	0.000237
# harman	12	0.000237
# harmful	12	0.000237
# harmony	12	0.000237
# harold	12	0.000237
# harper	12	0.000237
# harper's	12	0.000237
# harsh	12	0.000237
# haven	12	0.000237
# having	25	0.000237
# haymarket	12	0.000237
# head	25	0.000237
# headquarters	12	0.000237
# heads	12	0.000237
# health	25	0.000237
# hearing	25	0.000237
# heartily	12	0.000237
# heavily	12	0.000237
# heavy	25	0.000441
# heavy	12	0.000149
# heider	12	0.000237
# held	12	0.000237
# help	25	0.000237
# helped	25	0.000220
# helped	12	0.000149
# helpful	25	0.000237
# hemisphere	25	0.000237
# hennacy	12	0.000237
# henri	12	0.000237
# henry	12	0.000237
# herbert	12	0.000237
# heretic's	12	0.000237
# heritability	25	0.000237
# heritable	25	0.000237
# hern	12	0.000237
# heterogeneidad	12	0.000237
# heterosexual	12	0.000237
# heyday	12	0.000237
# heywood	12	0.000237
# heywood's	12	0.000237
# hfa	25	0.000237
# hierarchical	12	0.000237
# high	25	0.000880
# high	12	0.000149
# higher	25	0.000237
# high-functioning	25	0.000237
# high-level	25	0.000237
# highly	25	0.000237
# high-quality	25	0.000237
# high-resolution	25	0.000237
# himself	12	0.000237
# hirschfeld	12	0.000237
# historian	12	0.000237
# historical	12	0.000237
# historically	12	0.000237
# history	25	0.000661
# history	12	0.000149
# hitler	12	0.000237
# hoc	12	0.000237
# holdings	12	0.000237
# holds	12	0.000237
# holiday	12	0.000237
# home	25	0.000237
# homosexual	12	0.000237
# homosexuality	12	0.000237
# homosexuality.more	12	0.000237
# hopkins	25	0.000237
# horizontal	12	0.000237
# hormones	25	0.000237
# hospital	25	0.000237
# hosted	12	0.000237
# hourly	12	0.000237
# hours	12	0.000237
# housing	12	0.000237
# hugh	25	0.000237
# human	12	0.000237
# humanism	12	0.000237
# humans	12	0.000237
# hyperactivity	25	0.000237
# hyphenated	12	0.000237
# hypotheses	25	0.000237
# hypothesis	25	0.000237
# hypothesizes	25	0.000237
# iain	12	0.000237
# iberian	12	0.000237
# ibérica	12	0.000237
# icd-10	25	0.000237
# idea	25	0.000237
# ideal	12	0.000237
# ideas	12	0.000237
# identical	12	0.000237
# identifiable	25	0.000237
# identified	25	0.000237
# identify	25	0.000237
# ideological	12	0.000237
# ideologically	12	0.000237
# ideologies	12	0.000237
# ideology	12	0.000237
# idiosyncratic	25	0.000237
# idolatry	12	0.000237
# i.e	12	0.000237
# igualada	12	0.000237
# ii	12	0.000237
# il	12	0.000237
# illegal	12	0.000237
# illegalism	12	0.000237
# illegalism.however	12	0.000237
# illegalists	12	0.000237
# illich	12	0.000237
# illicit	25	0.000237
# illustrated	12	0.000237
# illustrating	25	0.000237
# image	12	0.000237
# imaginative	25	0.000237
# imaging	25	0.000237
# imbalance	25	0.000237
# imier	12	0.000237
# imitate	25	0.000237
# imitation	25	0.000237
# immune	25	0.000237
# immunizations	25	0.000237
# impact	12	0.000237
# impaired	25	0.000237
# impairment	25	0.000237
# impairments	25	0.000237
# impairments—who	25	0.000237
# imperative	12	0.000237
# implausible	25	0.000237
# implementation	12	0.000237
# implicate	25	0.000237
# implications	25	0.000237
# imply	25	0.000237
# importance	12	0.000237
# important	25	0.000220
# important	12	0.000149
# impossible	12	0.000237
# impoverishment	12	0.000237
# impractical	25	0.000237
# imprisoned	12	0.000237
# improve	25	0.000237
# improvement	25	0.000237
# improvements	25	0.000237
# improving	25	0.000237
# impuestas	12	0.000237
# impulsor	12	0.000237
# imrie	12	0.000237
# inability	25	0.000237
# inadequate	25	0.000441
# inadequate	12	0.000149
# inappropriate	25	0.000237
# inborn	25	0.000237
# incentives	25	0.000237
# incident	12	0.000237
# include	25	0.002201
# include	12	0.000149
# included	12	0.000237
# includes	25	0.000237
# including	25	0.000441
# including	12	0.000149
# income	25	0.000220
# income	12	0.000149
# incompatible	12	0.000237
# inconclusive	25	0.000237
# incorporated	12	0.000237
# increase	25	0.000237
# increased	25	0.000237
# increasing	25	0.000237
# increasingly	25	0.000661
# increasingly	12	0.000149
# independence	25	0.000237
# independent	25	0.000237
# independently	25	0.000237
# indicate	25	0.000237
# indication	25	0.000237
# indicator	25	0.000237
# indigenous	12	0.000237
# indirect	25	0.000220
# indirect	12	0.000149
# indirectamente	12	0.000237
# indirectly	12	0.000237
# individual	25	0.000661
# individual	12	0.000149
# individualism	12	0.000237
# individualist	12	0.000237
# individualista	12	0.000237
# individualist-anarchism	12	0.000237
# individualistes	12	0.000237
# individualistic	12	0.000237
# individualists	12	0.000237
# individuality	12	0.000237
# individualization	12	0.000237
# individually	25	0.000237
# individuals	25	0.006824
# individuals	12	0.000149
# individual's	25	0.000220
# individual's	12	0.000149
# induce	25	0.000237
# industrial	12	0.000237
# inequality	12	0.000237
# infamous	12	0.000237
# infancy	25	0.000237
# infantile	25	0.000237
# infants	25	0.000237
# infant's	25	0.000237
# infectious	25	0.000237
# infed	12	0.000237
# inference	25	0.000237
# inflation-adjusted	25	0.000237
# influence	25	0.000441
# influence	12	0.000149
# influenced	25	0.000220
# influenced	12	0.000149
# influences	12	0.000237
# influential	12	0.000237
# informal	12	0.000237
# informales	12	0.000237
# information	25	0.000661
# information	12	0.000149
# informed	12	0.000237
# infoshop.org	12	0.000237
# inheritance	25	0.000237
# inherited	25	0.000237
# inhibit	25	0.000237
# inhibition	25	0.000237
# initial	25	0.000220
# initial	12	0.000149
# initially	25	0.000220
# initially	12	0.000149
# initiated	25	0.000237
# initiatives	12	0.000237
# injure	25	0.000237
# inside	25	0.000220
# inside	12	0.000149
# insistence	25	0.000237
# insisting	25	0.000237
# insomnia	25	0.000237
# inspiration	12	0.000237
# inspire	12	0.000237
# inspired	12	0.000237
# instead	25	0.000880
# instead	12	0.000149
# institution	12	0.000237
# instruction	12	0.000237
# instruments	25	0.000237
# insumisión	12	0.000237
# insurance	25	0.000237
# insurrection	12	0.000237
# insurrectionary	12	0.000237
# intact	25	0.000237
# intégraient	12	0.000237
# integrated	25	0.000237
# integrating	25	0.000237
# intellectual	25	0.000441
# intellectual	12	0.000149
# intellectuals	12	0.000237
# intelligence	25	0.000237
# intended	25	0.000237
# intense	25	0.000237
# intensive	25	0.000237
# intentions	25	0.000237
# interaction	25	0.000237
# interactions	25	0.000237
# interchangeably	25	0.000220
# interchangeably	12	0.000149
# interestintersecting	12	0.000237
# interests	25	0.000237
# interfere	25	0.000237
# interferes	25	0.000237
# internal	25	0.000220
# internal	12	0.000149
# ...
# seen	12	0.000237
# segunda	12	0.000237
# selectively	25	0.000237
# selectivity	25	0.000237
# self	25	0.000237
# self-admiration	25	0.000237
# self-assertion	12	0.000237
# self-care	25	0.000237
# self-creation	12	0.000237
# self-defense	12	0.000237
# self-determination	25	0.000237
# self-determined	12	0.000237
# self-governance	12	0.000237
# self-injurious	25	0.000237
# self-injury	25	0.000237
# self-interest	12	0.000237
# self-managed	12	0.000237
# self-management	12	0.000237
# self-managing	12	0.000237
# self-ownership	12	0.000237
# self-realisation	12	0.000237
# self-referential	25	0.000237
# self-understanding	12	0.000237
# semistructured	25	0.000237
# sending	12	0.000237
# senior	12	0.000237
# sensation	25	0.000237
# sense	25	0.000441
# sense	12	0.000149
# sensitivity	25	0.000237
# sensory	25	0.000237
# separate	25	0.000237
# separating	25	0.000237
# september	12	0.000237
# será	12	0.000237
# series	12	0.000237
# serotonin	25	0.000237
# serves	12	0.000237
# service	25	0.000237
# service.mutualist	12	0.000237
# services	25	0.000441
# services	12	0.000149
# servitude	12	0.000237
# set	25	0.000441
# set	12	0.000149
# setback	12	0.000237
# setting	25	0.000220
# setting	12	0.000149
# seven	12	0.000237
# seventeen	12	0.000237
# severe	25	0.000237
# severely	25	0.000237
# severity	25	0.000237
# sex	25	0.000220
# sex	12	0.000149
# sexual	12	0.000237
# sexuality	25	0.000220
# sexuality	12	0.000149
# shaken	12	0.000237
# share	25	0.000237
# sharing	25	0.000237
# sharp	25	0.000220
# sharp	12	0.000149
# sharpley	12	0.000237
# sharply	12	0.000237
# sheltered	25	0.000237
# shifting	25	0.000237
# short	12	0.000237
# short-lived	12	0.000237
# showed	25	0.000237
# shown	25	0.000237
# shows	25	0.000237
# shtime	12	0.000237
# sibling	25	0.000237
# siblings	25	0.000237
# sickness	25	0.000237
# sides	12	0.000237
# siècle	12	0.000237
# signals	25	0.000237
# significant	25	0.000220
# significant	12	0.000149
# significantly	25	0.000237
# signs	25	0.000237
# silent	25	0.000237
# silvio	12	0.000237
# similar	25	0.000220
# similar	12	0.000149
# similarities	25	0.000237
# similarly	12	0.000237
# simon	12	0.000237
# simple	25	0.000220
# simple	12	0.000149
# simply	25	0.000441
# simply	12	0.000149
# simulation	25	0.000237
# simultaneously	12	0.000237
# sindacale	12	0.000237
# sindicale	12	0.000237
# sinful	12	0.000237
# single	25	0.001541
# single	12	0.000149
# single-gene	25	0.000237
# sinope	12	0.000237
# situated	12	0.000237
# situation	12	0.000237
# situationism	12	0.000237
# situationist	12	0.000237
# situations	25	0.000237
# sixties	12	0.000237
# sized	25	0.000237
# skill	25	0.000237
# skills	25	0.000237
# skin	25	0.000237
# skirda	12	0.000237
# slate.com	12	0.000237
# sleep	25	0.000237
# slevin	12	0.000237
# slogan	12	0.000237
# slower	25	0.000237
# small	25	0.000220
# small	12	0.000149
# smile	25	0.000237
# smoking	25	0.000237
# snow	12	0.000237
# social	25	0.007484
# social	12	0.000149
# socialdemocratic	12	0.000237
# socialism	12	0.000237
# socialist	12	0.000237
# socialists	12	0.000237
# societies	12	0.000237
# society	12	0.000237
# socioeconomic	25	0.000237
# socio-economic	12	0.000237
# sociological	25	0.000220
# sociological	12	0.000149
# soit	12	0.000237
# sol	12	0.000237
# solaire	12	0.000237
# solidarity	12	0.000237
# solvents	25	0.000237
# somewhat	25	0.000237
# sonnenburg	12	0.000237
# soon	25	0.000220
# soon	12	0.000149
# sorts	12	0.000237
# sought	12	0.000237
# soulless	25	0.000237
# source	12	0.000237
# sources	12	0.000237
# south	12	0.000237
# sovereign	12	0.000237
# sovereignty	12	0.000237
# soviet	12	0.000237
# soviet-allied	12	0.000237
# spain	12	0.000237
# spain's	12	0.000237
# spanish	12	0.000237
# speak	12	0.000237
# speaking	25	0.000237
# special	25	0.000441
# special	12	0.000149
# specialist	25	0.000237
# specialists	25	0.000237
# specialization	25	0.000237
# specializing	25	0.000237
# specific	25	0.001541
# specific	12	0.000149
# specificity	25	0.000237
# specified	25	0.000237
# spectrum	25	0.000237
# speech	25	0.000880
# speech	12	0.000149
# spelling	25	0.000237
# sperm	25	0.000237
# spines	25	0.000237
# spiritually	12	0.000237
# splinter	25	0.000237
# split	12	0.000237
# spoke	12	0.000237
# sponsored	12	0.000237
# spontaneous	25	0.000220
# spontaneous	12	0.000149
# spontaneously	25	0.000237
# spook	12	0.000237
# spooks	12	0.000237
# sprang	12	0.000237
# spread	12	0.000237
# square	12	0.000237
# squatter	12	0.000237
# squatters	12	0.000237
# st	12	0.000237
# stable	25	0.000237
# stacks	25	0.000237
# stage	25	0.000237
# staged	12	0.000237
# stalinist-led	12	0.000237
# stalinists	12	0.000237
# stance	12	0.000237
# standard	12	0.000237
# standardized	25	0.000237
# start	25	0.000237
# started	12	0.000237
# starting	25	0.000220
# starting	12	0.000149
# state	12	0.000237
# stated	12	0.000237
# stateless	12	0.000237
# statements	12	0.000237
# state-protected	12	0.000237
# states	25	0.001100
# states	12	0.000149
# steadfastly	12	0.000237
# steady	25	0.000237
# stephen	12	0.000237
# steps	25	0.000237
# stereotyped	25	0.000237
# stereotypy	25	0.000237
# stigma	25	0.000237
# stimulants	25	0.000237
# stimuli	25	0.000237
# stirner	12	0.000237
# stirnerists	12	0.000237
# stirner's	12	0.000237
# stoicism	12	0.000237
# storage	25	0.000237
# story	25	0.000237
# strains	12	0.000237
# strategy	12	0.000237
# strength	25	0.000441
# strength	12	0.000149
# stress	25	0.000237
# stressed	12	0.000237
# strike	12	0.000237
# strikebreakers	12	0.000237
# striking	25	0.000237
# strikingly	25	0.000237
# stringham	12	0.000237
# strong	25	0.000661
# strong	12	0.000149
# strongest	12	0.000237
# stronghold	12	0.000237
# strongholds	12	0.000237
# strongly	25	0.000441
# strongly	12	0.000149
# structural	25	0.000237
# structure	12	0.000237
# structured	25	0.000237
# structures	25	0.000441
# structures	12	0.000149
# struggle	12	0.000237
# struggle-approach	12	0.000237
# struggles	12	0.000237
# student	25	0.000237
# students	12	0.000237
# studies	25	0.000237
# study	25	0.003302
# study	12	0.000149
# subdivisions	25	0.000237
# subgroups	25	0.000237
# subject	25	0.000237
# subjective	12	0.000237
# subjectivity	12	0.000237
# subjects	12	0.000237
# subsequently	12	0.000237
# subset	25	0.000237
# substantial	25	0.000237
# substantiated	25	0.000237
# subtle	12	0.000237
# subtype	25	0.000237
# subtypes	25	0.000237
# subversive	12	0.000237
# subversives	12	0.000237
# success	25	0.000220
# success	12	0.000149
# successful	25	0.000441
# successful	12	0.000149
# successfully	25	0.000237
# successor	12	0.000237
# suffer	25	0.000237
# sufficient	12	0.000237
# suffix	12	0.000237
# suffocated	25	0.000237
# suggest	25	0.001761
# suggest	12	0.000149
# suggested	25	0.000237
# suggesting	25	0.000237
# suggests	25	0.000237
# suicide	12	0.000237
# summerhill	12	0.000237
# superior	25	0.000237
# superiority	25	0.000237
# supervision	25	0.000237
# support	25	0.001761
# support	12	0.000149
# supported	25	0.000880
# supported	12	0.000149
# supporters	12	0.000237
# supporting	12	0.000237
# suppressed	12	0.000237
# suppression	12	0.000237
# surge	12	0.000237
# surrealist	12	0.000237
# surround	25	0.000237
# surroundings	12	0.000237
# surveyor	12	0.000237
# survived	12	0.000237
# sus	12	0.000237
# suspicion	25	0.000237
# sustained	25	0.000237
# sweden	12	0.000237
# swedish	25	0.000441
# swedish	12	0.000149
# swiss	25	0.000220
# swiss	12	0.000149
# sylvain	12	0.000237
# symbolic	25	0.000237
# symbolism	12	0.000237
# symbols	25	0.000237
# symptom	25	0.000237
# symptoms	25	0.000237
# symptomsautistic	25	0.000237
# synapses	25	0.000237
# synaptic	25	0.000237
# synchronization	25	0.000237
# synchronized	25	0.000237
# syncretic	12	0.000237
# syndicalism	12	0.000237
# syndicalist	12	0.000237
# syndicalists	12	0.000237
# syndromal	25	0.000237
# syndrome	25	0.000237
# syndromes	25	0.000237
# synonym	12	0.000237
# synthesis	25	0.000220
# synthesis	12	0.000149
# synthesist	12	0.000237
# systematic	25	0.000441
# systematic	12	0.000149
# systemize—that	25	0.000237
# systemizing	25	0.000237
# systems	25	0.000661
# systems	12	0.000149
# table	25	0.000237
# tactic	12	0.000237
# tactical	12	0.000237
# tactics	12	0.000237
# tailored	25	0.000237
# taken	12	0.000237
# taking	25	0.000661
# taking	12	0.000149
# talents	25	0.000237
# talk	25	0.000237
# tantrums	25	0.000237
# taoism	12	0.000237
# taoist	12	0.000237
# targeting	25	0.000237
# tarrida	12	0.000237
# task-positive	25	0.000237
# tasks	25	0.000237
# taught	12	0.000237
# tax	12	0.000237
# teaching	25	0.000220
# teaching	12	0.000149
# teachings	12	0.000237
# technical	12	0.000237
# techniques	12	0.000237
# technologies	25	0.000220
# technologies	12	0.000149
# technology	25	0.000220
# technology	12	0.000149
# television	25	0.000237
# temple	25	0.000237
# temporary	12	0.000237
# tend	25	0.000237
# tendencias	12	0.000237
# tendencies	12	0.000237
# tendency	12	0.000237
# tensor	25	0.000237
# tentative	25	0.000237
# teratogens	25	0.000237
# term	25	0.000220
# term	12	0.000149
# terminology	25	0.000661
# terminology	12	0.000149
# terms	12	0.000237
# territories	12	0.000237
# territory	12	0.000237
# terrorism	12	0.000237
# terry	12	0.000237
# test	25	0.000237
# tested	25	0.000237
# testing	25	0.000237
# tests	25	0.000237
# teufel	12	0.000237
# text	12	0.000237
# texts	12	0.000237
# themes	12	0.000237
# theology	12	0.000237
# theoretical	12	0.000237
# théorie	12	0.000237
# theories	25	0.001541
# theories	12	0.000149
# theorists	12	0.000237
# theory	25	0.003522
# theory	12	0.000149
# theory—enhanced	25	0.000237
# therapies	25	0.000237
# therapy	25	0.000237
# thief	12	0.000237
# things	25	0.000441
# things	12	0.000149
# thinkers	12	0.000237
# thinking	25	0.000237
# thinner	25	0.000237
# thoreau	12	0.000237
# thought	25	0.000661
# thought	12	0.000149
# three-quarters	25	0.000237
# three-year-old	25	0.000237
# thresholds	25	0.000237
# thrown	12	0.000237
# thursday	12	0.000237
# time	25	0.000441
# time	12	0.000149
# times	25	0.000220
# times	12	0.000149
# timing	25	0.000237
# tiny	12	0.000237
# today	12	0.000237
# toddlers	25	0.000237
# toe	25	0.000237
# toggling	25	0.000237
# toleration	12	0.000237
# tolstoy	12	0.000237
# tolstoy's	12	0.000237
# tom	12	0.000237
# tone	25	0.000237
# took	25	0.000220
# took	12	0.000149
# tools	25	0.000237
# topics	12	0.000237
# tormey	12	0.000237
# tortured	12	0.000237
# total	25	0.000237
# tourette	25	0.000237
# towns	12	0.000237
# toy	25	0.000237
# trabajo	12	0.000237
# traceable	25	0.000237
# traced	25	0.000220
# traced	12	0.000149
# trade	12	0.000237
# trades	12	0.000237
# trade-union	12	0.000237
# tradition	12	0.000237
# traditional	25	0.000220
# traditional	12	0.000149
# traditions	12	0.000237
# training	25	0.000237
# traits	25	0.000237
# transaction	12	0.000237
# transactions	12	0.000237
# transcendentalist	12	0.000237
# transferred	12	0.000237
# transformed	12	0.000237
# transient	25	0.000237
# transition	12	0.000237
# translated	12	0.000237
# translation	25	0.000237
# transmitted	12	0.000237
# transport	25	0.000237
# treat	25	0.000237
# treated	25	0.000441
# treated	12	0.000149
# treating	25	0.000237
# treatment	25	0.003302
# treatment	12	0.000149
# treatments	25	0.000237
# triad	25	0.000237
# tries	12	0.000237
# trivia	25	0.000237
# troops	12	0.000237
# truda	12	0.000237
# truda's	12	0.000237
# true	25	0.000441
# true	12	0.000149
# truth	12	0.000237
# tsarist	12	0.000237
# tuberous	25	0.000237
# tucker	12	0.000237
# turn	25	0.000441
# turn	12	0.000149
# turns	25	0.000237
# twentieth	12	0.000237
# twenty-first	12	0.000237
# twins	25	0.000237
# two-thirds	25	0.000237
# two-word	25	0.000237
# type	25	0.000237
# types	12	0.000237
# typical	25	0.000237
# typically	25	0.000237
# tyrannicides	12	0.000237
# uk	25	0.000661
# uk	12	0.000149
# ukraine	12	0.000237
# ukraine—anarchist	12	0.000237
# ulrike	12	0.000237
# ultimate	12	0.000237
# umanita	12	0.000237
# una	12	0.000237
# unaffected	25	0.000237
# unanimously	12	0.000237
# unbalanced	25	0.000237
# unbridgeable	12	0.000237
# uncertain	25	0.000237
# unchanging	25	0.000237
# unclear	25	0.000237
# underconnectivity	25	0.000237
# underdiagnosis	25	0.000237
# underestimate	25	0.000237
# underfunctioning	25	0.000237
# underground	12	0.000237
# underlies	25	0.000237
# underlying	25	0.000237
# under-responsivity	25	0.000237
# understand	25	0.000237
# understanding	25	0.000237
# understood	25	0.000237
# underway	25	0.000237
# undesirable	12	0.000237
# undiagnosed	25	0.000237
# undoubtedly	12	0.000237
# une	12	0.000237
# unfortunate	12	0.000237
# unidentified	25	0.000237
# unifying	25	0.000237
# union	12	0.000237
# unione	12	0.000237
# unionism	12	0.000237
# unionist	12	0.000237
# unionists	12	0.000237
# unions	12	0.000237
# unité	12	0.000237
# united	25	0.000441
# united	12	0.000149
# unity."bob	12	0.000237
# università	12	0.000237
# university	25	0.000220
# university	12	0.000149
# unjust	12	0.000237
# unknown	12	0.000237
# unless	12	0.000237
# unlike	25	0.000441
# unlike	12	0.000149
# unlikely	25	0.000237
# unnecessary	12	0.000237
# uno	12	0.000237
# unreimbursed	25	0.000237
# unrelated	25	0.000237
# unresolved	25	0.000237
# unschooling	12	0.000237
# unselected	25	0.000237
# unsuccessful	12	0.000237
# unsupported	25	0.000237
# unusual	25	0.000237
# unvarying	25	0.000237
# update	25	0.000237
# updating	12	0.000237
# upheaval	12	0.000237
# uphold[ing	12	0.000237
# uprising	12	0.000237
# uprisings	12	0.000237
# uri	12	0.000237
# uruguayan	12	0.000237
# u.s	12	0.000237
# use	25	0.000880
# use	12	0.000149
# used	25	0.002201
# used	12	0.000149
# useful	25	0.000237
# uses	25	0.000441
# uses	12	0.000149
# using	25	0.000661
# using	12	0.000149
# ussr	12	0.000237
# usual	25	0.000237
# usually	25	0.000441
# usually	12	0.000149
# utilitarian	12	0.000237
# vaccination	25	0.000237
# vaccine	25	0.000237
# vaccines	25	0.000237
# valets	12	0.000237
# validation	25	0.000237
# validity	25	0.000237
# value	25	0.000220
# value	12	0.000149
# values	12	0.000237
# variable	25	0.000237
# variants	25	0.000237
# variation	25	0.000237
# variations	25	0.000237
# variations—spontaneous	25	0.000237
# variety	12	0.000237
# various	25	0.000441
# various	12	0.000149
# varlet	12	0.000237
# varying	25	0.000441
# varying	12	0.000149
# vast	12	0.000237
# veganism	12	0.000237
# venomous	12	0.000237
# veracity	25	0.000237
# verbose	25	0.000237
# version	12	0.000237
# versus	25	0.000237
# veteran	12	0.000237
# victorious	12	0.000237
# victory	12	0.000237
# vida.""la	12	0.000237
# vienna	25	0.000237
# vietnam	12	0.000237
# view	25	0.000220
# view	12	0.000149
# viewed	25	0.000220
# viewed	12	0.000149
# viewpoints	25	0.000237
# views	12	0.000237
# vigour	12	0.000237
# village	12	0.000237
# villagers	12	0.000237
# vincent	12	0.000237
# vinculadas	12	0.000237
# violence	25	0.000220
# violence	12	0.000149
# violent	25	0.000220
# violent	12	0.000149
# virginia	12	0.000237
# virtual	12	0.000237
# vision	25	0.000237
# visual	25	0.000237
# visually	25	0.000237
# vocabulary	25	0.000237
# vocal	25	0.000237
# voices	12	0.000237
# vol	12	0.000237
# volin	12	0.000237
# voline	12	0.000237
# voltairine	12	0.000237
# volume	12	0.000237
# voluntaria	12	0.000237
# voluntary	12	0.000237
# volunteer	25	0.000237
# volunteered	12	0.000237
# votes	12	0.000237
# vraiment	12	0.000237
# vv	12	0.000237
# wage	12	0.000237
# wages	12	0.000237
# waisbrooker	12	0.000237
# walden	12	0.000237
# walker	12	0.000237
# walking	25	0.000237
# want	12	0.000237
# war	12	0.000237
# ward	12	0.000237
# warned	12	0.000237
# warranted	25	0.000237
# warren	12	0.000237
# watch	12	0.000237
# wave	12	0.000237
# waving	25	0.000237
# way	25	0.000441
# way	12	0.000149
# ways	12	0.000237
# weak	25	0.000237
# weaker	25	0.000237
# weaknesses	25	0.000237
# weblog	12	0.000237
# webpage	12	0.000237
# website	12	0.000237
# weekly	12	0.000237
# weeks	25	0.000237
# weitling	12	0.000237
# well-being	25	0.000237
# well-documented	25	0.000237
# well-established	25	0.000237
# wendy	12	0.000237
# went	12	0.000237
# west	12	0.000237
# western	12	0.000237
# westminster	12	0.000237
# whites	12	0.000237
# wide	25	0.000237
# widely	25	0.000441
# widely	12	0.000149
# wider	12	0.000237
# widespread	25	0.000220
# widespread	12	0.000149
# wild	25	0.000237
# wilde	12	0.000237
# wilhelm	12	0.000237
# willful	12	0.000237
# william	12	0.000237
# wing	12	0.000237
# winstanley	12	0.000237
# wishes	12	0.000237
# withdrawal	25	0.000237
# woman	12	0.000237
# women	12	0.000237
# women's	12	0.000237
# won	12	0.000237
# woodcock	12	0.000237
# woodcock's	12	0.000237
# woodcut-style	12	0.000237
# word	25	0.000880
# word	12	0.000149
# words	25	0.000237
# work	25	0.000661
# work	12	0.000149
# worked	12	0.000237
# worker	12	0.000237
# worker-owned	12	0.000237
# workers	12	0.000237
# worker's	12	0.000237
# working	25	0.000220
# working	12	0.000149
# workingmen's	12	0.000237
# workplace	12	0.000237
# workplaces	12	0.000237
# works	12	0.000237
# world	12	0.000237
# worldwide	25	0.000220
# worldwide	12	0.000149
# worse	25	0.000237
# wreszin	12	0.000237
# write	12	0.000237
# writing	12	0.000237
# writings	12	0.000237
# wrote	12	0.000237
# wto	12	0.000237
# x	25	0.000237
# xavier	12	0.000237
# y	12	0.000237
# yawning	12	0.000237
# year	25	0.000441
# year	12	0.000149
# years	25	0.002642
# years	12	0.000149
# york	12	0.000237
# young	25	0.000880
# young	12	0.000149
# younger	25	0.000220
# younger	12	0.000149
# youth	12	0.000237
# ytak	12	0.000237
# zeno	12	0.000237
# zhuangzi	12	0.000237
# zhuangzi's	12	0.000237
# zisly	12	0.000237
# znet	12	0.000237
# αὐτός	25	0.000237
# ιζειν	12	0.000237
# ισμός	12	0.000237
# ἀν	12	0.000237
# ἄναρχος	12	0.000237
# ἀρχή	12	0.000237
# ἀρχός	12	0.000237

# %%
# %%bash
#
# OUT_DIR="tf_idf"
# NUM_REDUCERS=8
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR} > /dev/null
#
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -D mapred.jab.name="Streaming tf_idf" \
#     -D mapreduce.job.reduces=${NUM_REDUCERS} \
#     -files mapper.py,reducer.py,/datasets/stop_words_en.txt \
#     -mapper "python mapper.py" \
#     -reducer "python reducer.py" \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR} > /dev/null
#
# hdfs dfs -cat tf_idf/* | grep -P 'labor\t12\t' | cut -f3
# Out:
# 0%however	6970	0.003838
# 0&\mathrm{if	7583	0.003838
# 0(8)320-1234	2061	0.003838
# 0)).(1	7143	0.003838
# 0,03	5188	0.003838
# 0,1,...,n	1635	0.003838
# 0,1,0	6026	0.003838
# 0,1,\dots,n	4594	0.003838
# 0,5	3107	0.003838
# 0,50	4845	0.003838
# 18/04/16 09:19:23 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/04/16 09:19:23 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/04/16 09:19:24 INFO mapred.FileInputFormat: Total input files to process : 1
# 18/04/16 09:19:25 INFO mapreduce.JobSubmitter: number of splits:2
# 18/04/16 09:19:25 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1523870263342_0002
# 18/04/16 09:19:25 INFO impl.YarnClientImpl: Submitted application application_1523870263342_0002
# 18/04/16 09:19:25 INFO mapreduce.Job: The url to track the job: http://9c5ea2b8efd5:8088/proxy/application_1523870263342_0002/
# 18/04/16 09:19:25 INFO mapreduce.Job: Running job: job_1523870263342_0002
# 18/04/16 09:19:32 INFO mapreduce.Job: Job job_1523870263342_0002 running in uber mode : false
# 18/04/16 09:19:32 INFO mapreduce.Job:  map 0% reduce 0%
# 18/04/16 09:19:50 INFO mapreduce.Job:  map 62% reduce 0%
# 18/04/16 09:19:55 INFO mapreduce.Job:  map 80% reduce 0%
# 18/04/16 09:19:56 INFO mapreduce.Job:  map 100% reduce 0%
# 18/04/16 09:20:14 INFO mapreduce.Job:  map 100% reduce 12%
# 18/04/16 09:20:16 INFO mapreduce.Job:  map 100% reduce 13%
# 18/04/16 09:20:18 INFO mapreduce.Job:  map 100% reduce 25%
# 18/04/16 09:20:22 INFO mapreduce.Job:  map 100% reduce 38%
# 18/04/16 09:20:23 INFO mapreduce.Job:  map 100% reduce 50%
# 18/04/16 09:20:24 INFO mapreduce.Job:  map 100% reduce 75%
# 18/04/16 09:20:30 INFO mapreduce.Job:  map 100% reduce 100%
# 18/04/16 09:20:31 INFO mapreduce.Job: Job job_1523870263342_0002 completed successfully
# 18/04/16 09:20:31 INFO mapreduce.Job: Counters: 50
# 	File System Counters
# 		FILE: Number of bytes read=83708136
# 		FILE: Number of bytes written=168815616
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=76761713
# 		HDFS: Number of read operations=30
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=8
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=40421
# 		Total time spent by all reduces in occupied slots (ms)=149674
# 		Total time spent by all map tasks (ms)=40421
# 		Total time spent by all reduce tasks (ms)=149674
# 		Total vcore-milliseconds taken by all map tasks=40421
# 		Total vcore-milliseconds taken by all reduce tasks=149674
# 		Total megabyte-milliseconds taken by all map tasks=41391104
# 		Total megabyte-milliseconds taken by all reduce tasks=153266176
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=3472743
# 		Map output bytes=76762592
# 		Map output materialized bytes=83708184
# 		Input split bytes=228
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=426865
# 		Reduce shuffle bytes=83708184
# 		Reduce input records=3472743
# 		Reduce output records=3472685
# 		Spilled Records=6945486
# 		Shuffled Maps =16
# 		Failed Shuffles=0
# 		Merged Map outputs=16
# 		GC time elapsed (ms)=2114
# 		CPU time spent (ms)=69080
# 		Physical memory (bytes) snapshot=1907585024
# 		Virtual memory (bytes) snapshot=19660169216
# 		Total committed heap usage (bytes)=1289748480
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=76761713
# 18/04/16 09:20:31 INFO streaming.StreamJob: Output directory: tf_idf
# cat: Unable to write to output stream.
